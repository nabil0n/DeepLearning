# %% [markdown]
# # Playing Black Jack
# We want to train a network that plays black jack.
#
# We are using the [Gymnasium black jack](https://gymnasium.farama.org/environments/toy_text/blackjack/) library as game.
#
# ## Actions
# The agent will have 2 options, hit (take another card) or stick (stop taking cards)
#
# ## Environment (observation space)
# The environment consists of a 3-tuple containing: the player’s current sum, the value of the dealer’s one showing card (1-10 where 1 is ace), and whether the player holds a usable ace (0 or 1).
#
# The observation is returned as (int(), int(), int()).
#
#
# ## Rewards
# - +1 point for winning
# - -1 point for loosing
# - 0 points for draw

# %%
import numpy as np
import random
from IPython import display
from IPython.display import clear_output
from collections import deque

import gymnasium as gym

from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Dense, Embedding, Reshape
from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt

# %%
env = gym.make("Blackjack-v1", render_mode="rgb_array")
action_size = env.action_space.n
state_size = 3

print('Number of actions: {}'.format(action_size))
# Out:
# Number of actions: 2

# %% [markdown]
# # Playing the game with random actions

# %%
env.reset()
for i in range(10):
    plt.imshow(env.render())
    display.display(plt.gcf())
    display.clear_output(wait=True)
    next_state, reward, done, _, _ = env.step(env.action_space.sample()) # take a random action
    if done:
        plt.imshow(env.render())
        display.display(plt.gcf())
        display.clear_output(wait=True)
        print(f'Player hand: {env.unwrapped.player}, {sum(env.unwrapped.player)}')
        print(f'Reward: {reward}')
        print(f'Dealer hand: {env.unwrapped.dealer}, {sum(env.unwrapped.dealer)}')
        break
# Out:
# Player hand: [3, 7, 10], 20
# Reward: 1.0
# Dealer hand: [8, 5, 2, 9], 24

# %% [markdown]
# ## Crate agent

# %%
# DQN Agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=200)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state, verbose=0)
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, min(len(self.memory), batch_size))
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state, verbose=0)[0]))
            target_f = self.model.predict(state, verbose=0)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
agent = DQNAgent(state_size, action_size)
# Out:
# c:\KODA\ITHS\9_Deep Learning\DeepLearning\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
state = env.reset()[0]
state = np.reshape(state, [1, state_size])
for i in range(10):
    plt.imshow(env.render())
    display.display(plt.gcf())
    display.clear_output(wait=True)
    next_state, reward, done, _, _ = env.step(agent.act(state))
    if done:
        plt.imshow(env.render())
        display.display(plt.gcf())
        display.clear_output(wait=True)
        print(f'Player hand: {env.unwrapped.player}, {sum(env.unwrapped.player)}')
        print(f'Reward: {reward}')
        print(f'Dealer hand: {env.unwrapped.dealer}, {sum(env.unwrapped.dealer)}')
        break
# Out:
# Player hand: [1, 4, 10, 4, 5], 24
# Reward: -1.0
# Dealer hand: [8, 9], 17

# %% [markdown]
# # Train agent

# %%
# Training the Agent
episodes = 50
batch_size = 16

# %%
for e in range(episodes):
    state = env.reset()[0]
    state = np.reshape(state, [1, state_size])
    
    for time in range(10):  # Maximum number of steps
        action = agent.act(state)
        next_state, reward, done, _, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        if done:
            print("Episode: {}/{}, Score: {}, Epsilon: {:.2f}".format(e, episodes, reward, agent.epsilon))
        if done and (e % 20 == 0):
            print("Episode: {}/{}, Score: {}, Epsilon: {:.2f}".format(e, episodes, reward, agent.epsilon))
            break

        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
# Out:
# Episode: 0/50, Score: -1.0, Epsilon: 1.00
# Episode: 0/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: 1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 1/50, Score: -1.0, Epsilon: 1.00
# Episode: 2/50, Score: 1.0, Epsilon: 1.00
# Episode: 2/50, Score: 1.0, Epsilon: 1.00
# Episode: 2/50, Score: 1.0, Epsilon: 1.00
# Episode: 2/50, Score: 1.0, Epsilon: 1.00
# Episode: 2/50, Score: -1.0, Epsilon: 1.00
# Episode: 2/50, Score: -1.0, Epsilon: 0.99
# Episode: 2/50, Score: 0.0, Epsilon: 0.99
# Episode: 2/50, Score: 0.0, Epsilon: 0.99
# Episode: 2/50, Score: -1.0, Epsilon: 0.98
# Episode: 3/50, Score: 1.0, Epsilon: 0.98
# Episode: 3/50, Score: 1.0, Epsilon: 0.97
# Episode: 3/50, Score: -1.0, Epsilon: 0.97
# Episode: 3/50, Score: 0.0, Epsilon: 0.96
# Episode: 3/50, Score: 0.0, Epsilon: 0.96
# Episode: 3/50, Score: -1.0, Epsilon: 0.95
# Episode: 3/50, Score: 0.0, Epsilon: 0.95
# Episode: 3/50, Score: 0.0, Epsilon: 0.94
# Episode: 3/50, Score: -1.0, Epsilon: 0.94
# Episode: 3/50, Score: 0.0, Epsilon: 0.93
# Episode: 4/50, Score: -1.0, Epsilon: 0.92
# Episode: 4/50, Score: -1.0, Epsilon: 0.92
# Episode: 4/50, Score: -1.0, Epsilon: 0.91
# Episode: 4/50, Score: -1.0, Epsilon: 0.91
# Episode: 4/50, Score: -1.0, Epsilon: 0.90
# Episode: 4/50, Score: -1.0, Epsilon: 0.90
# Episode: 4/50, Score: -1.0, Epsilon: 0.90
# Episode: 4/50, Score: -1.0, Epsilon: 0.89
# Episode: 4/50, Score: -1.0, Epsilon: 0.89
# Episode: 5/50, Score: -1.0, Epsilon: 0.88
# Episode: 5/50, Score: 0.0, Epsilon: 0.87
# Episode: 5/50, Score: -1.0, Epsilon: 0.87
# Episode: 5/50, Score: -1.0, Epsilon: 0.86
# Episode: 5/50, Score: -1.0, Epsilon: 0.86
# Episode: 5/50, Score: -1.0, Epsilon: 0.86
# Episode: 5/50, Score: -1.0, Epsilon: 0.85
# Episode: 5/50, Score: -1.0, Epsilon: 0.85
# Episode: 5/50, Score: -1.0, Epsilon: 0.84
# Episode: 6/50, Score: -1.0, Epsilon: 0.84
# Episode: 6/50, Score: -1.0, Epsilon: 0.83
# Episode: 6/50, Score: -1.0, Epsilon: 0.83
# Episode: 6/50, Score: -1.0, Epsilon: 0.83
# Episode: 6/50, Score: -1.0, Epsilon: 0.82
# Episode: 6/50, Score: -1.0, Epsilon: 0.82
# Episode: 6/50, Score: -1.0, Epsilon: 0.81
# Episode: 6/50, Score: -1.0, Epsilon: 0.81
# Episode: 6/50, Score: -1.0, Epsilon: 0.81
# Episode: 6/50, Score: -1.0, Epsilon: 0.80
# Episode: 7/50, Score: -1.0, Epsilon: 0.79
# Episode: 7/50, Score: -1.0, Epsilon: 0.79
# Episode: 7/50, Score: -1.0, Epsilon: 0.79
# Episode: 7/50, Score: -1.0, Epsilon: 0.78
# Episode: 7/50, Score: -1.0, Epsilon: 0.78
# Episode: 7/50, Score: -1.0, Epsilon: 0.77
# Episode: 7/50, Score: -1.0, Epsilon: 0.77
# Episode: 7/50, Score: -1.0, Epsilon: 0.77
# Episode: 7/50, Score: -1.0, Epsilon: 0.76
# Episode: 8/50, Score: 1.0, Epsilon: 0.76
# Episode: 8/50, Score: 1.0, Epsilon: 0.76
# Episode: 8/50, Score: 1.0, Epsilon: 0.75
# Episode: 8/50, Score: 1.0, Epsilon: 0.75
# Episode: 8/50, Score: 1.0, Epsilon: 0.74
# Episode: 8/50, Score: 1.0, Epsilon: 0.74
# Episode: 8/50, Score: -1.0, Epsilon: 0.73
# Episode: 8/50, Score: 0.0, Epsilon: 0.73
# Episode: 8/50, Score: 0.0, Epsilon: 0.73
# Episode: 9/50, Score: -1.0, Epsilon: 0.72
# Episode: 9/50, Score: -1.0, Epsilon: 0.72
# Episode: 9/50, Score: -1.0, Epsilon: 0.71
# Episode: 9/50, Score: -1.0, Epsilon: 0.71
# Episode: 9/50, Score: -1.0, Epsilon: 0.71
# Episode: 9/50, Score: -1.0, Epsilon: 0.70
# Episode: 9/50, Score: -1.0, Epsilon: 0.70
# Episode: 9/50, Score: -1.0, Epsilon: 0.70
# Episode: 9/50, Score: -1.0, Epsilon: 0.69
# Episode: 9/50, Score: -1.0, Epsilon: 0.69
# Episode: 10/50, Score: 1.0, Epsilon: 0.69
# Episode: 10/50, Score: -1.0, Epsilon: 0.68
# Episode: 10/50, Score: -1.0, Epsilon: 0.68
# Episode: 10/50, Score: -1.0, Epsilon: 0.68
# Episode: 10/50, Score: -1.0, Epsilon: 0.67
# Episode: 10/50, Score: -1.0, Epsilon: 0.67
# Episode: 10/50, Score: -1.0, Epsilon: 0.67
# Episode: 10/50, Score: -1.0, Epsilon: 0.66
# Episode: 10/50, Score: -1.0, Epsilon: 0.66
# Episode: 10/50, Score: -1.0, Epsilon: 0.66
# Episode: 11/50, Score: -1.0, Epsilon: 0.65
# Episode: 11/50, Score: -1.0, Epsilon: 0.65
# Episode: 11/50, Score: -1.0, Epsilon: 0.65
# Episode: 11/50, Score: -1.0, Epsilon: 0.64
# Episode: 11/50, Score: -1.0, Epsilon: 0.64
# Episode: 11/50, Score: -1.0, Epsilon: 0.64
# Episode: 11/50, Score: -1.0, Epsilon: 0.63
# Episode: 11/50, Score: -1.0, Epsilon: 0.63
# Episode: 11/50, Score: -1.0, Epsilon: 0.63
# Episode: 11/50, Score: -1.0, Epsilon: 0.62
# Episode: 12/50, Score: -1.0, Epsilon: 0.62
# Episode: 12/50, Score: -1.0, Epsilon: 0.62
# Episode: 12/50, Score: -1.0, Epsilon: 0.61
# Episode: 12/50, Score: -1.0, Epsilon: 0.61
# Episode: 12/50, Score: -1.0, Epsilon: 0.61
# Episode: 12/50, Score: -1.0, Epsilon: 0.61
# Episode: 12/50, Score: -1.0, Epsilon: 0.60
# Episode: 12/50, Score: -1.0, Epsilon: 0.60
# Episode: 12/50, Score: -1.0, Epsilon: 0.60
# Episode: 12/50, Score: -1.0, Epsilon: 0.59
# Episode: 13/50, Score: -1.0, Epsilon: 0.59
# Episode: 13/50, Score: -1.0, Epsilon: 0.59
# Episode: 13/50, Score: -1.0, Epsilon: 0.58
# Episode: 13/50, Score: -1.0, Epsilon: 0.58
# Episode: 13/50, Score: -1.0, Epsilon: 0.58
# Episode: 13/50, Score: -1.0, Epsilon: 0.58
# Episode: 13/50, Score: -1.0, Epsilon: 0.57
# Episode: 13/50, Score: -1.0, Epsilon: 0.57
# Episode: 13/50, Score: -1.0, Epsilon: 0.57
# Episode: 13/50, Score: -1.0, Epsilon: 0.56
# Episode: 14/50, Score: -1.0, Epsilon: 0.56
# Episode: 14/50, Score: 1.0, Epsilon: 0.55
# Episode: 14/50, Score: -1.0, Epsilon: 0.55
# Episode: 14/50, Score: -1.0, Epsilon: 0.55
# Episode: 14/50, Score: -1.0, Epsilon: 0.54
# Episode: 14/50, Score: -1.0, Epsilon: 0.54
# Episode: 14/50, Score: -1.0, Epsilon: 0.54
# Episode: 15/50, Score: 1.0, Epsilon: 0.53
# Episode: 15/50, Score: 1.0, Epsilon: 0.53
# Episode: 15/50, Score: 1.0, Epsilon: 0.53
# Episode: 15/50, Score: -1.0, Epsilon: 0.52
# Episode: 15/50, Score: -1.0, Epsilon: 0.52
# Episode: 15/50, Score: -1.0, Epsilon: 0.52
# Episode: 15/50, Score: -1.0, Epsilon: 0.52
# Episode: 15/50, Score: -1.0, Epsilon: 0.51
# Episode: 15/50, Score: -1.0, Epsilon: 0.51
# Episode: 16/50, Score: -1.0, Epsilon: 0.51
# Episode: 16/50, Score: -1.0, Epsilon: 0.50
# Episode: 16/50, Score: -1.0, Epsilon: 0.50
# Episode: 16/50, Score: -1.0, Epsilon: 0.50
# Episode: 16/50, Score: -1.0, Epsilon: 0.50
# Episode: 16/50, Score: -1.0, Epsilon: 0.49
# Episode: 16/50, Score: -1.0, Epsilon: 0.49
# Episode: 16/50, Score: -1.0, Epsilon: 0.49
# Episode: 16/50, Score: -1.0, Epsilon: 0.49
# Episode: 17/50, Score: 1.0, Epsilon: 0.48
# Episode: 17/50, Score: 1.0, Epsilon: 0.48
# Episode: 17/50, Score: -1.0, Epsilon: 0.48
# Episode: 17/50, Score: 0.0, Epsilon: 0.47
# Episode: 17/50, Score: 0.0, Epsilon: 0.47
# Episode: 17/50, Score: -1.0, Epsilon: 0.47
# Episode: 17/50, Score: -1.0, Epsilon: 0.47
# Episode: 17/50, Score: 0.0, Epsilon: 0.46
# Episode: 17/50, Score: 0.0, Epsilon: 0.46
# Episode: 18/50, Score: -1.0, Epsilon: 0.46
# Episode: 18/50, Score: -1.0, Epsilon: 0.46
# Episode: 18/50, Score: -1.0, Epsilon: 0.46
# Episode: 18/50, Score: -1.0, Epsilon: 0.45
# Episode: 18/50, Score: -1.0, Epsilon: 0.45
# Episode: 18/50, Score: -1.0, Epsilon: 0.45
# Episode: 18/50, Score: -1.0, Epsilon: 0.45
# Episode: 18/50, Score: -1.0, Epsilon: 0.44
# Episode: 18/50, Score: -1.0, Epsilon: 0.44
# Episode: 18/50, Score: -1.0, Epsilon: 0.44
# Episode: 19/50, Score: 1.0, Epsilon: 0.44
# Episode: 19/50, Score: 1.0, Epsilon: 0.44
# Episode: 19/50, Score: 1.0, Epsilon: 0.43
# Episode: 19/50, Score: 1.0, Epsilon: 0.43
# Episode: 19/50, Score: 1.0, Epsilon: 0.42
# Episode: 19/50, Score: -1.0, Epsilon: 0.42
# Episode: 19/50, Score: 0.0, Epsilon: 0.42
# Episode: 19/50, Score: 0.0, Epsilon: 0.42
# Episode: 20/50, Score: 1.0, Epsilon: 0.41
# Episode: 20/50, Score: 1.0, Epsilon: 0.41
# Episode: 21/50, Score: 1.0, Epsilon: 0.41
# Episode: 21/50, Score: 1.0, Epsilon: 0.41
# Episode: 21/50, Score: 1.0, Epsilon: 0.41
# Episode: 21/50, Score: 1.0, Epsilon: 0.41
# Episode: 21/50, Score: 1.0, Epsilon: 0.41
# Episode: 21/50, Score: 1.0, Epsilon: 0.40
# Episode: 21/50, Score: 1.0, Epsilon: 0.40
# Episode: 21/50, Score: 1.0, Epsilon: 0.40
# Episode: 22/50, Score: -1.0, Epsilon: 0.39
# Episode: 22/50, Score: -1.0, Epsilon: 0.39
# Episode: 22/50, Score: -1.0, Epsilon: 0.39
# Episode: 22/50, Score: -1.0, Epsilon: 0.39
# Episode: 22/50, Score: -1.0, Epsilon: 0.39
# Episode: 22/50, Score: -1.0, Epsilon: 0.38
# Episode: 22/50, Score: -1.0, Epsilon: 0.38
# Episode: 22/50, Score: -1.0, Epsilon: 0.38
# Episode: 22/50, Score: -1.0, Epsilon: 0.38
# Episode: 22/50, Score: -1.0, Epsilon: 0.38
# Episode: 23/50, Score: -1.0, Epsilon: 0.37
# Episode: 23/50, Score: -1.0, Epsilon: 0.37
# Episode: 23/50, Score: -1.0, Epsilon: 0.37
# Episode: 23/50, Score: -1.0, Epsilon: 0.37
# Episode: 23/50, Score: -1.0, Epsilon: 0.37
# Episode: 23/50, Score: -1.0, Epsilon: 0.37
# Episode: 23/50, Score: -1.0, Epsilon: 0.36
# Episode: 23/50, Score: -1.0, Epsilon: 0.36
# Episode: 23/50, Score: -1.0, Epsilon: 0.36
# Episode: 23/50, Score: -1.0, Epsilon: 0.36
# Episode: 24/50, Score: 1.0, Epsilon: 0.36
# Episode: 24/50, Score: 1.0, Epsilon: 0.35
# Episode: 24/50, Score: 1.0, Epsilon: 0.35
# Episode: 24/50, Score: -1.0, Epsilon: 0.35
# Episode: 24/50, Score: -1.0, Epsilon: 0.35
# Episode: 24/50, Score: -1.0, Epsilon: 0.35
# Episode: 24/50, Score: 0.0, Epsilon: 0.35
# Episode: 24/50, Score: 0.0, Epsilon: 0.34
# Episode: 24/50, Score: 0.0, Epsilon: 0.34
# Episode: 24/50, Score: 0.0, Epsilon: 0.34
# Episode: 25/50, Score: 1.0, Epsilon: 0.34
# Episode: 25/50, Score: 1.0, Epsilon: 0.34
# Episode: 25/50, Score: 1.0, Epsilon: 0.34
# Episode: 25/50, Score: 1.0, Epsilon: 0.33
# Episode: 25/50, Score: 1.0, Epsilon: 0.33
# Episode: 25/50, Score: 1.0, Epsilon: 0.33
# Episode: 25/50, Score: 1.0, Epsilon: 0.33
# Episode: 25/50, Score: 1.0, Epsilon: 0.33
# Episode: 25/50, Score: 1.0, Epsilon: 0.33
# Episode: 25/50, Score: 1.0, Epsilon: 0.32
# Episode: 26/50, Score: -1.0, Epsilon: 0.32
# Episode: 26/50, Score: -1.0, Epsilon: 0.32
# Episode: 26/50, Score: -1.0, Epsilon: 0.32
# Episode: 26/50, Score: -1.0, Epsilon: 0.32
# Episode: 26/50, Score: -1.0, Epsilon: 0.32
# Episode: 26/50, Score: -1.0, Epsilon: 0.31
# Episode: 26/50, Score: -1.0, Epsilon: 0.31
# Episode: 26/50, Score: -1.0, Epsilon: 0.31
# Episode: 26/50, Score: -1.0, Epsilon: 0.31
# Episode: 26/50, Score: -1.0, Epsilon: 0.31
# Episode: 27/50, Score: 1.0, Epsilon: 0.30
# Episode: 27/50, Score: 1.0, Epsilon: 0.30
# Episode: 27/50, Score: 1.0, Epsilon: 0.30
# Episode: 27/50, Score: 1.0, Epsilon: 0.30
# Episode: 27/50, Score: 1.0, Epsilon: 0.30
# Episode: 27/50, Score: 1.0, Epsilon: 0.30
# Episode: 27/50, Score: 1.0, Epsilon: 0.30
# Episode: 27/50, Score: 1.0, Epsilon: 0.29
# Episode: 27/50, Score: 1.0, Epsilon: 0.29
# Episode: 28/50, Score: -1.0, Epsilon: 0.29
# Episode: 28/50, Score: -1.0, Epsilon: 0.29
# Episode: 28/50, Score: -1.0, Epsilon: 0.29
# Episode: 28/50, Score: -1.0, Epsilon: 0.29
# Episode: 28/50, Score: -1.0, Epsilon: 0.28
# Episode: 28/50, Score: -1.0, Epsilon: 0.28
# Episode: 28/50, Score: -1.0, Epsilon: 0.28
# Episode: 28/50, Score: -1.0, Epsilon: 0.28
# Episode: 28/50, Score: -1.0, Epsilon: 0.28
# Episode: 29/50, Score: -1.0, Epsilon: 0.28
# Episode: 29/50, Score: -1.0, Epsilon: 0.28
# Episode: 29/50, Score: -1.0, Epsilon: 0.27
# Episode: 29/50, Score: -1.0, Epsilon: 0.27
# Episode: 29/50, Score: -1.0, Epsilon: 0.27
# Episode: 29/50, Score: -1.0, Epsilon: 0.27
# Episode: 29/50, Score: -1.0, Epsilon: 0.27
# Episode: 29/50, Score: -1.0, Epsilon: 0.27
# Episode: 29/50, Score: -1.0, Epsilon: 0.26
# Episode: 30/50, Score: -1.0, Epsilon: 0.26
# Episode: 30/50, Score: -1.0, Epsilon: 0.26
# Episode: 30/50, Score: -1.0, Epsilon: 0.26
# Episode: 30/50, Score: -1.0, Epsilon: 0.26
# Episode: 30/50, Score: -1.0, Epsilon: 0.26
# Episode: 30/50, Score: -1.0, Epsilon: 0.26
# Episode: 30/50, Score: -1.0, Epsilon: 0.26
# Episode: 30/50, Score: -1.0, Epsilon: 0.25
# Episode: 30/50, Score: -1.0, Epsilon: 0.25
# Episode: 30/50, Score: -1.0, Epsilon: 0.25
# Episode: 31/50, Score: -1.0, Epsilon: 0.25
# Episode: 31/50, Score: -1.0, Epsilon: 0.25
# Episode: 31/50, Score: -1.0, Epsilon: 0.25
# Episode: 31/50, Score: -1.0, Epsilon: 0.25
# Episode: 31/50, Score: -1.0, Epsilon: 0.24
# Episode: 31/50, Score: -1.0, Epsilon: 0.24
# Episode: 31/50, Score: -1.0, Epsilon: 0.24
# Episode: 31/50, Score: -1.0, Epsilon: 0.24
# Episode: 31/50, Score: -1.0, Epsilon: 0.24
# Episode: 32/50, Score: -1.0, Epsilon: 0.24
# Episode: 32/50, Score: -1.0, Epsilon: 0.23
# Episode: 32/50, Score: -1.0, Epsilon: 0.23
# Episode: 32/50, Score: -1.0, Epsilon: 0.23
# Episode: 32/50, Score: -1.0, Epsilon: 0.23
# Episode: 32/50, Score: -1.0, Epsilon: 0.23
# Episode: 32/50, Score: -1.0, Epsilon: 0.23
# Episode: 32/50, Score: -1.0, Epsilon: 0.23
# Episode: 33/50, Score: -1.0, Epsilon: 0.23
# Episode: 33/50, Score: -1.0, Epsilon: 0.22
# Episode: 33/50, Score: -1.0, Epsilon: 0.22
# Episode: 33/50, Score: -1.0, Epsilon: 0.22
# Episode: 33/50, Score: -1.0, Epsilon: 0.22
# Episode: 33/50, Score: -1.0, Epsilon: 0.22
# Episode: 33/50, Score: -1.0, Epsilon: 0.22
# Episode: 33/50, Score: -1.0, Epsilon: 0.22
# Episode: 33/50, Score: -1.0, Epsilon: 0.22
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 34/50, Score: -1.0, Epsilon: 0.21
# Episode: 35/50, Score: -1.0, Epsilon: 0.21
# Episode: 35/50, Score: -1.0, Epsilon: 0.20
# Episode: 35/50, Score: -1.0, Epsilon: 0.20
# Episode: 35/50, Score: -1.0, Epsilon: 0.20
# Episode: 35/50, Score: -1.0, Epsilon: 0.20
# Episode: 35/50, Score: -1.0, Epsilon: 0.20
# Episode: 35/50, Score: -1.0, Epsilon: 0.20
# Episode: 35/50, Score: -1.0, Epsilon: 0.20
# Episode: 35/50, Score: -1.0, Epsilon: 0.20
# Episode: 36/50, Score: 1.0, Epsilon: 0.20
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 36/50, Score: 1.0, Epsilon: 0.19
# Episode: 37/50, Score: -1.0, Epsilon: 0.19
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 37/50, Score: -1.0, Epsilon: 0.18
# Episode: 38/50, Score: -1.0, Epsilon: 0.18
# Episode: 38/50, Score: -1.0, Epsilon: 0.18
# Episode: 38/50, Score: -1.0, Epsilon: 0.17
# Episode: 38/50, Score: -1.0, Epsilon: 0.17
# Episode: 38/50, Score: -1.0, Epsilon: 0.17
# Episode: 38/50, Score: -1.0, Epsilon: 0.17
# Episode: 38/50, Score: -1.0, Epsilon: 0.17
# Episode: 38/50, Score: -1.0, Epsilon: 0.17
# Episode: 38/50, Score: -1.0, Epsilon: 0.17
# Episode: 38/50, Score: -1.0, Epsilon: 0.17
# Episode: 39/50, Score: 1.0, Epsilon: 0.17
# Episode: 39/50, Score: 1.0, Epsilon: 0.17
# Episode: 39/50, Score: 1.0, Epsilon: 0.17
# Episode: 39/50, Score: 1.0, Epsilon: 0.17
# Episode: 39/50, Score: 1.0, Epsilon: 0.16
# Episode: 39/50, Score: 1.0, Epsilon: 0.16
# Episode: 39/50, Score: 1.0, Epsilon: 0.16
# Episode: 39/50, Score: 1.0, Epsilon: 0.16
# Episode: 39/50, Score: 1.0, Epsilon: 0.16
# Episode: 39/50, Score: 1.0, Epsilon: 0.16
# Episode: 40/50, Score: -1.0, Epsilon: 0.16
# Episode: 40/50, Score: -1.0, Epsilon: 0.16
# Episode: 41/50, Score: -1.0, Epsilon: 0.16
# Episode: 41/50, Score: -1.0, Epsilon: 0.16
# Episode: 41/50, Score: -1.0, Epsilon: 0.16
# Episode: 41/50, Score: -1.0, Epsilon: 0.16
# Episode: 41/50, Score: -1.0, Epsilon: 0.16
# Episode: 41/50, Score: -1.0, Epsilon: 0.16
# Episode: 41/50, Score: -1.0, Epsilon: 0.15
# Episode: 41/50, Score: -1.0, Epsilon: 0.15
# Episode: 41/50, Score: -1.0, Epsilon: 0.15
# Episode: 41/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 42/50, Score: -1.0, Epsilon: 0.15
# Episode: 43/50, Score: -1.0, Epsilon: 0.14
# Episode: 43/50, Score: -1.0, Epsilon: 0.14
# Episode: 43/50, Score: -1.0, Epsilon: 0.14
# Episode: 43/50, Score: -1.0, Epsilon: 0.14
# Episode: 43/50, Score: -1.0, Epsilon: 0.14
# Episode: 43/50, Score: -1.0, Epsilon: 0.14
# Episode: 43/50, Score: -1.0, Epsilon: 0.14
# Episode: 43/50, Score: -1.0, Epsilon: 0.14
# Episode: 44/50, Score: -1.0, Epsilon: 0.14
# Episode: 44/50, Score: -1.0, Epsilon: 0.14
# Episode: 44/50, Score: -1.0, Epsilon: 0.14
# Episode: 44/50, Score: -1.0, Epsilon: 0.13
# Episode: 44/50, Score: -1.0, Epsilon: 0.13
# Episode: 44/50, Score: -1.0, Epsilon: 0.13
# Episode: 44/50, Score: -1.0, Epsilon: 0.13
# Episode: 44/50, Score: -1.0, Epsilon: 0.13
# Episode: 44/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.13
# Episode: 45/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 46/50, Score: -1.0, Epsilon: 0.12
# Episode: 47/50, Score: -1.0, Epsilon: 0.12
# Episode: 47/50, Score: -1.0, Epsilon: 0.12
# Episode: 47/50, Score: -1.0, Epsilon: 0.12
# Episode: 47/50, Score: -1.0, Epsilon: 0.12
# Episode: 47/50, Score: -1.0, Epsilon: 0.12
# Episode: 47/50, Score: -1.0, Epsilon: 0.12
# Episode: 47/50, Score: -1.0, Epsilon: 0.11
# Episode: 47/50, Score: -1.0, Epsilon: 0.11
# Episode: 47/50, Score: -1.0, Epsilon: 0.11
# Episode: 47/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 48/50, Score: -1.0, Epsilon: 0.11
# Episode: 49/50, Score: -1.0, Epsilon: 0.11
# Episode: 49/50, Score: -1.0, Epsilon: 0.11
# Episode: 49/50, Score: -1.0, Epsilon: 0.11
# Episode: 49/50, Score: -1.0, Epsilon: 0.11
# Episode: 49/50, Score: -1.0, Epsilon: 0.10
# Episode: 49/50, Score: -1.0, Epsilon: 0.10
# Episode: 49/50, Score: -1.0, Epsilon: 0.10
# Episode: 49/50, Score: -1.0, Epsilon: 0.10
# Episode: 49/50, Score: -1.0, Epsilon: 0.10
# Episode: 49/50, Score: -1.0, Epsilon: 0.10

# %% [markdown]
# # Play the game with the agent

# %%
state = env.reset()[0]
state = np.reshape(state, [1, state_size])
for i in range(10):
    plt.imshow(env.render())
    display.display(plt.gcf())
    display.clear_output(wait=True)
    next_state, reward, done, _, _ = env.step(agent.act(state))
    if done:
        plt.imshow(env.render())
        display.display(plt.gcf())
        display.clear_output(wait=True)
        print(f'Player hand: {env.unwrapped.player}, {sum(env.unwrapped.player)}')
        print(f'Reward: {reward}')
        print(f'Dealer hand: {env.unwrapped.dealer}, {sum(env.unwrapped.dealer)}')
        break
# Out:
# Player hand: [10, 1, 3], 14
# Reward: -1.0
# Dealer hand: [1, 10], 11

# %% [markdown]
# # Tasks
# Experiment with the agent structure.
# - Layers
# - Activation functions
# - Epsilon
# - Gamma
# - Memory
# - Batch size
#
# Evaluate how many games the agent wins over time (For example 100+ games). How does it compare to just doing random actions?
